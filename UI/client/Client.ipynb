# %%
from tkinter import *
from tkinter import messagebox


def on_closing():
    if messagebox.askokcancel("Выход из приложения", "Хотите выйти из приложения?"):
        serverWindow.destroy()
        
def run_Button():
     messagebox.showinfo("Статус сервера", "Сервер запущен")

swHei = 600
swWid = 800
serverWindow = Tk()
serverWindow.protocol("WM_DELETE_WINDOW", on_closing)
serverWindow.title("Клиент")
serverWindow.resizable(0, 0)
serverWindow.wm_attributes("-topmost", 1)
serverWindow.iconbitmap("123.ico")
serverWindow.geometry(str(swWid)+'x'+str(swHei))

frame0 = Frame(serverWindow, width = 800, height = 100, bg = '#E0FFFF')
frame1 = Frame(serverWindow, width = 400, height = 100, bg = '#E0FFFF')
frame2 = Frame(serverWindow, width = 400, height = 100, bg = '#E0FFFF')
#frame3 = Frame(serverWindow, width = 800, height = 100, bg = '#E0FFFF')
frame4 = Frame(serverWindow, width = 800, height = 100, bg = '#E0FFFF')
frame5 = Frame(serverWindow, width = 800, height = 200, bg = '#E0FFFF')
frame6 = Frame(serverWindow, width = 800, height = 100, bg = '#E0FFFF')
frame7 = Frame(serverWindow, width = 400, height = 100, bg = '#E0FFFF')
frame8 = Frame(serverWindow, width = 400, height = 100, bg = '#E0FFFF')

frame0.place(relx = 0, rely = 0, relwidth = 1, relheight = 0.055)
frame1.place(relx = 0, rely = 0.04, relwidth = 0.5, relheight = 0.15)
frame2.place(relx = 0.5, rely = 0.04, relwidth = 0.5, relheight = 0.15)
frame6.place(relx = 0, rely = 0.13, relwidth = 1, relheight = 0.055)
frame7.place(relx = 0, rely = 0.17, relwidth = 0.5, relheight = 0.15)
frame8.place(relx = 0.5, rely = 0.17, relwidth = 0.5, relheight = 0.15)
frame4.place(relx = 0, rely = 0.32, relwidth = 1, relheight = 0.1)
frame5.place(relx = 0, rely = 0.38, relwidth = 1, relheight = 0.65)

mydir = ""
IP_adres = StringVar()
port = StringVar()
X = StringVar()
Y = StringVar()

IP_server_label = Label(frame0, text="IP адрес севера: 192.168.0.1", bg = '#E0FFFF')
IP_adres_label = Label(frame1, text="IP адрес:", bg = '#E0FFFF')
port_label = Label(frame2, text="Порт:", bg = '#E0FFFF')
coordin_label = Label(frame6, text="Координаты:", bg = '#E0FFFF')
x_label = Label(frame7, text="X:", bg = '#E0FFFF')
y_label = Label(frame8, text="Y:", bg = '#E0FFFF')

IP_adres_entry = Entry(frame1, textvariable=IP_adres)
port_entry = Entry(frame2, textvariable=port)
x_entry = Entry(frame7, textvariable=X)
y_entry = Entry(frame8, textvariable=Y)

IP_server_label.pack(side = LEFT, anchor="w", padx=300, pady=10)

IP_adres_label.pack(side = LEFT, anchor="w", padx=35, pady=30)
IP_adres_entry.pack(side = LEFT, anchor="w", padx=10, pady=30, ipadx = 50)

port_label.pack(side = LEFT, anchor="w", padx=35, pady=30)
port_entry.pack(side = LEFT, anchor="w", padx=10, pady=30, ipadx = 50)

coordin_label.pack(side = LEFT, anchor="w", padx=35, pady=10)

x_label.pack(side = LEFT, anchor="w", padx=35, pady=30)
x_entry.pack(side = LEFT, anchor="w", padx=10, pady=30, ipadx = 50)

y_label.pack(side = LEFT, anchor="w", padx=35, pady=30)
y_entry.pack(side = LEFT, anchor="w", padx=10, pady=30, ipadx = 50)

status_servera_label = Label(frame4, text="Статус подключения:", bg = '#E0FFFF')
status_servera_label.place(relx = 0.35, rely = 0.10)

canvas = Canvas(frame4, width = 100, height = 40, bg = '#E0FFFF')

r = canvas.create_oval(10, 10, 30, 30, fill="#708090")
y = canvas.create_oval(40, 10, 60, 30, fill="#708090")
g = canvas.create_oval(70, 10, 90, 30, fill="#708090")

canvas.place(relx = 0.50, rely = 0)

canvas1 = Canvas(frame5, height=500, width=800, bg = '#E0FFFF')
img = PhotoImage(file = 'cmd_client.png') 
image = canvas1.create_image(0, 0, anchor='nw',image=img)

canvas1.pack(side = BOTTOM)


serverWindow.mainloop()

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5013-80A4
#
#  Directory of C:\Users\Њ и \Downloads
#
# 12/08/2022  12:31 PM    <DIR>          .
# 12/08/2022  12:31 PM    <DIR>          ..
# 12/07/2022  05:19 PM    <DIR>          .ipynb_checkpoints
# 10/06/2021  10:29 PM            11,758 [NNMClub.to]_VMware Workstation 15 Pro 15.5.6 Build 16341506 RePack by KpoJIuK.torrent
# 12/07/2022  05:22 PM            67,646 123.ico
# 12/04/2022  11:47 PM            50,523 6KB_Buben_referet.docx
# 12/04/2022  11:07 PM           494,278 6KB_Buben_referet.pdf
# 07/30/2012  01:32 AM           640,476 abstract_1.cpt
# 04/11/2020  02:00 PM       488,908,696 Anaconda3-2020.02-Windows-x86_64.exe
# 05/15/2021  04:59 PM        12,302,064 apache-tomcat-9.0.46.exe
# 02/19/2021  07:15 PM       117,306,912 arduino-1.8.12-windows.exe
# 07/01/2020  09:23 AM           304,663 Basics.html
# 05/04/2020  09:52 PM             3,054 bot.zip
# 08/05/2022  06:24 PM           491,141 business correspondence training.doc.pdf
# 12/08/2022  12:31 PM            29,700 cmd_client.png
# 11/15/2022  03:15 PM           333,765 cmd_server.png
# 11/17/2020  04:46 PM        62,636,856 DiscordSetup.exe
# 10/27/2021  10:39 PM         7,453,044 electronic_workbench_v5.12_setup.EXE
# 12/07/2022  12:41 AM             1,385 Form_.cls
# 12/07/2022  11:42 PM           443,797 Gayd_po_testu_u_Afonenko.docx
# 05/03/2020  07:57 PM        46,891,904 Git-2.26.2-64-bit.exe
# 03/20/2022  10:35 PM       286,294,688 GMT20220317-165933_Recording_1600x1024.mp4
# 10/21/2020  11:35 PM        12,004,216 HPPSdr.exe
# 09/27/2020  06:29 PM       600,354,904 ideaIC-2020.2.2.exe
# 05/16/2021  02:34 PM       764,705,864 ideaIU-2021.1.1.exe
# 11/15/2022  04:29 PM    <DIR>          image_processing-main
# 11/15/2022  03:46 PM         2,890,931 image_processing-main.zip
# 09/27/2020  07:45 PM       167,435,408 jdk-15_windows-x64_bin.exe
# 10/08/2022  07:49 AM    <DIR>          kali-linux-2022.3-vmware-amd64
# 11/13/2022  01:19 AM           496,051 konteynerizatsiya-kak-ocherednoy-etap-razvitiya-transportnyh-sistem.pdf
# 10/21/2020  11:45 PM        85,144,592 LJ1018_1020_1022_Full_Solution.exe
# 11/03/2020  08:10 PM           107,012 Mathworks Matlab R2020b (9.9.0) Windows x64 [rutracker-5944475].torrent
# 01/20/2022  08:04 PM    <DIR>          MF210MFDriverV450WPRU
# 01/20/2022  08:03 PM       125,772,016 MF210MFDriverV450WPRU.exe
# 11/13/2022  11:40 PM        23,254,324 moluch_118_1.zip
# 11/13/2022  01:19 AM        40,325,577 moluch_416_8ImlCSl.zip
# 10/08/2021  10:40 PM         2,306,048 msmpisdk.msi
# 11/26/2021  11:33 AM       493,006,848 mysql-installer-community-8.0.27.1.msi
# 04/25/2020  04:38 PM        81,268,832 Postman-win64-7.23.0-Setup.exe
# 12/07/2022  05:12 PM             5,008 Project.ipynb
# 03/05/2021  11:05 AM       112,450,275 Proteus 8.1 Pro Portable.exe
# 05/05/2020  07:20 PM       280,243,048 pycharm-community-2020.1.exe
# 11/15/2022  03:15 PM           333,765 pyimage2.png
# 11/15/2022  03:15 PM           333,765 pyimage3.png
# 02/06/2022  10:30 PM        28,909,456 python-3.9.10-amd64.exe
# 03/15/2021  12:31 AM           551,240 ReversoSetup.exe
# 06/07/2022  11:06 PM         1,380,936 rufus-3.18.exe
# 03/13/2022  11:45 AM           703,901 russia-invades-ukraine-british-english-teacher.pdf
# 12/01/2022  07:27 PM     3,249,803,264 Russian_windows_server_2008_r2_standard_enterprise_datacenter_sp1_x64.iso
# 12/08/2022  12:25 AM             4,267 Server (1).ipynb
# 12/08/2022  12:26 PM             5,593 Server.ipynb
# 02/12/2021  12:13 PM         7,896,399 ShareX-13.4.0-setup.exe
# 04/09/2020  11:20 AM        71,692,816 SlackSetup.exe
# 07/16/2020  12:03 PM        78,353,520 spotify-1-1-34-694.exe
# 11/28/2021  09:30 AM         6,376,336 SQL2019-SSEI-Expr.exe
# 11/28/2021  10:15 AM       703,907,824 SSMS-Setup-RUS.exe
# 08/02/2020  11:03 PM         1,573,568 SteamSetup.exe
# 12/17/2021  12:35 AM    <DIR>          step-by-step-ldx1ik2x2
# 04/25/2020  04:22 PM        27,347,176 TeamViewer_Setup.exe
# 12/01/2022  07:15 PM    <DIR>          Telegram Desktop
# 04/11/2020  01:58 PM        21,996,656 telegram-for-desktop-2-0 (1).exe
# 04/09/2020  10:06 AM        21,996,656 telegram-for-desktop-2-0.exe
# 01/20/2022  08:58 PM    <DIR>          ToolBox4911mf18WinRU
# 01/20/2022  08:55 PM        10,547,296 ToolBox4911mf18WinRU.exe
# 10/07/2021  12:02 AM     3,071,934,464 ubuntu-20.04.3-desktop-amd64.iso
# 06/07/2022  11:01 PM           258,178 ubuntu-20.04.4-desktop-amd64.iso (1).torrent
# 06/07/2022  11:00 PM           258,178 ubuntu-20.04.4-desktop-amd64.iso.torrent
# 08/05/2022  06:24 PM           140,463 useful phrases correspondence.docx.pdf
# 11/03/2020  08:30 PM         5,116,976 uTorrent.exe
# 04/09/2020  10:08 AM        96,719,536 ViberSetup.exe
# 11/28/2021  12:52 AM         1,465,304 vs_community__1781473404.1633721664 (1).exe
# 04/09/2020  11:19 AM         1,388,248 vs_community__95591729.1586420351.exe
# 11/14/2021  12:10 PM        79,944,464 VSCodeUserSetup-x64-1.62.2.exe
# 01/20/2022  08:57 PM         1,134,688 winaddressbooktoolv1152.exe
# 04/24/2020  12:33 PM         3,394,320 winrar-x64-590ru.exe
# 11/27/2020  03:01 PM         3,393,480 winrar-x64-591ru.exe
# 05/12/2020  04:05 PM            78,168 Zoom_o42l8sofizku_8157e33965a54f36.exe
# 03/24/2022  03:53 PM            42,928 ’ҐбвЁа®ў ­ЁҐ.docx
# 03/23/2022  10:32 PM        10,400,195 ’ҐбвЁа®ўйЁЄ б ­г«п.pdf
# 11/21/2022  10:33 AM            14,412 вЁвг«м­ЁЄ.docx
#               71 File(s) 11,325,835,740 bytes
#                9 Dir(s)  10,495,762,432 bytes free
